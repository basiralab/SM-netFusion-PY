# %%
run SM_netFusion_demo.py
# Out:
# The number of selected features is automatically set to:  5
# To change it, please set Nf variable inside SM_netFusion_demo to a different integer.
# The option for displaying the estimated atlases and selected features at each run of the cross-validation algorithm is set to: 1
#
# To turn it off, please set displayResults variable inside SM_netFusion_demo to 0.
#
# Note that displaying the results at each run will slow down the demo.
#
# Select the number of class 1 graphs: 12
# Select the number of class 2 graphs: 10
# Select the number of nodes (i.e., ROIS for brain graphs): 50
#
# Please wait... This process takes some time according to user's inputs...
# 0
# SIMLR highly recommends you to perform PCA first on the data
#
# Please use the in-line function fast_pca on your input
#
# SIMLR highly recommends you to perform PCA first on the data
#
# Please use the in-line function fast_pca on your input
# 1
# SIMLR highly recommends you to perform PCA first on the data
#
# ...
